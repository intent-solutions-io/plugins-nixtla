# %% [markdown]
# # StatsForecast Demo
#
# This notebook demonstrates time series forecasting with Nixtla's StatsForecast library.

# %%
# Install dependencies
# !pip install statsforecast pandas matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsforecast import StatsForecast
from statsforecast.models import AutoETS, AutoARIMA, SeasonalNaive

# %% [markdown]
# ## Load Data
#
# Load your time series data in Nixtla format (unique_id, ds, y).

# %%
# TODO: Load your data here
# df = pd.read_csv('your_data.csv')
# df['ds'] = pd.to_datetime(df['ds'])

# %% [markdown]
# ## Configure Models

# %%
sf = StatsForecast(
    models=[
        AutoETS(season_length=7),
        AutoARIMA(season_length=7),
        SeasonalNaive(season_length=7)
    ],
    freq='D',
    n_jobs=-1
)

# %% [markdown]
# ## Generate Forecasts

# %%
# forecasts = sf.forecast(df=df, h=14)
# forecasts.head()

# %% [markdown]
# ## Visualize Results

# %%
# sf.plot(df, forecasts)
# plt.show()
