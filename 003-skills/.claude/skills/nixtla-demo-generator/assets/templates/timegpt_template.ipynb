# %% [markdown]
# # TimeGPT Demo
#
# This notebook demonstrates zero-shot forecasting with Nixtla's TimeGPT API.

# %%
# Install dependencies
# !pip install nixtla pandas matplotlib

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from nixtla import NixtlaClient

# %% [markdown]
# ## Initialize Client
#
# Set your API key from https://dashboard.nixtla.io/

# %%
client = NixtlaClient(
    api_key=os.environ.get('NIXTLA_API_KEY', 'your-api-key')
)

# %% [markdown]
# ## Load Data
#
# Load your time series data in Nixtla format (unique_id, ds, y).

# %%
# TODO: Load your data here
# df = pd.read_csv('your_data.csv')
# df['ds'] = pd.to_datetime(df['ds'])

# %% [markdown]
# ## Generate Forecasts

# %%
# forecasts = client.forecast(
#     df=df,
#     h=14,
#     freq='D',
#     level=[80, 90, 95]
# )
# forecasts.head()

# %% [markdown]
# ## Visualize with Confidence Intervals

# %%
# client.plot(df, forecasts, level=[80, 90, 95])
# plt.show()

# %% [markdown]
# ## Anomaly Detection

# %%
# anomalies = client.detect_anomalies(df=df, freq='D')
# anomalies[anomalies['anomaly'] == True]
